# %% [markdown]
# > **Training-Wheels Reminder:**
# > Use Cursor only to help you think—not to think for you.
# > Before asking Cursor to write code or analysis, write out *your own idea* first:
# > - What data you want
# > - What steps you believe are needed
# > - What the code should roughly do
# > - What the output should look like
# >
# > Then ask Cursor to refine, correct, or optimize what *you* already started.
# > This notebook is for building the skill, not outsourcing it.

# %% [markdown]
# # Lightning Network Yield = Capital Model
#
# **Goal:** Model Lightning Network routing revenue as a function of deployed capital
#
# **Skills:**
# - Capital efficiency modeling
# - Yield calculations
# - Risk-adjusted returns

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# TODO: Define yield model (routing revenue / capital deployed)
# TODO: Analyze capital efficiency
# TODO: Compare different node strategies
