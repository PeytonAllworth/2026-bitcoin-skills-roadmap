# %% [markdown]
# > **Training-Wheels Reminder:**
# > Use Cursor only to help you think—not to think for you.
# > Before asking Cursor to write code or analysis, write out *your own idea* first:
# > - What data you want
# > - What steps you believe are needed
# > - What the code should roughly do
# > - What the output should look like
# >
# > Then ask Cursor to refine, correct, or optimize what *you* already started.
# > This notebook is for building the skill, not outsourcing it.

# %% [markdown]
# # Mempool Congestion vs Fee Regression Analysis
#
# **Goal:** Analyze the relationship between mempool congestion and transaction fees
#
# **Skills:**
# - Linear regression
# - Rolling regressions
# - Statistical analysis
# - Causal reasoning

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# TODO: Load mempool data and fee data
# TODO: Run OLS regression
# TODO: Implement rolling regression
# TODO: Visualize results
